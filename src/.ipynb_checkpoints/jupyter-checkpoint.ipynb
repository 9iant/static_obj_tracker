# %%
import sys

#----------------for offline process---------
import numpy 
import matplotlib.pyplot as plt
import pandas as pd
import time
#-----------------from SORT------------------
import os
import matplotlib
# matplotlib.use('TkAgg')
import matplotlib.patches as patches
import glob
import time
import argparse

# %%
data = pd.read_csv("../rec/image_server_for_test.csv")
data = data.drop(data.index[296:len(data)])
data.tail()
# Out:
#             stamp  seq_tw  drone_position_x  drone_position_y  \
# 291  1.628080e+09     719          3.598358          0.492628
# 292  1.628080e+09     720          3.714417          0.497346
# 293  1.628080e+09     721          3.765696          0.498939
# 294  1.628080e+09     722          3.864339          0.498278
# 295  1.628080e+09     723          3.921497          0.497635
#
#      drone_position_z  drone_position_qx  drone_position_qy  \
# 291          0.781007          -0.001844          -0.033350
# 292          0.780973          -0.004176          -0.034432
# 293          0.782376          -0.004658          -0.028187
# 294          0.773764          -0.003076          -0.023842
# 295          0.776413          -0.002690          -0.020454
#
#      drone_position_qz  drone_position_qw yolo_label  yolo_xmin  yolo_xmax  \
# 291          -0.006344           0.999422    soldier        288        348
# 292          -0.011061           0.999337    soldier        286        345
# 293          -0.013175           0.999505    soldier        279        343
# 294          -0.020084           0.999509    soldier        270        337
# 295          -0.022977           0.999523    soldier        266        334
#
#      yolo_ymin  yolo_ymax  yolo_confidence  object_global_position_2d_x  \
# 291        196        425         0.965958                     9.341733
# 292        199        433         0.980953                     9.302734
# 293        201        429         0.973441                     9.153665
# 294        189        418         0.991816                     9.151124
# 295        183        424         0.992858                     9.117592
#
#      object_global_position_2d_y  object_global_position_2d_z
# 291                     0.401121                          0.0
# 292                     0.368221                          0.0
# 293                     0.393512                          0.0
# 294                     0.379125                          0.0
# 295                     0.391599                          0.0

# %%
ls_data = []
result = []
index = 0
for key, value in data.iterrows():

    if (index+2)> len(data): # to deal with last item
        break

    result.append(value)
    if value.seq_tw != data.loc[index+1,'seq_tw']: # if the seq_tw is same, store them into one item.
        ls_data.append(result)
        result = []
        
    index += 1

# %%
for i
# Out:
# [stamp                          1628079686.208116
# seq_tw                                         7
# drone_position_x                       -0.004009
# drone_position_y                          0.0015
# drone_position_z                         0.00085
# drone_position_qx                      -0.006234
# drone_position_qy                      -0.019201
# drone_position_qz                      -0.001094
# drone_position_qw                       0.999796
# yolo_label                               soldier
# yolo_xmin                                    289
# yolo_xmax                                    330
# yolo_ymin                                    161
# yolo_ymax                                    270
# yolo_confidence                         0.987346
# object_global_position_2d_x             9.744872
# object_global_position_2d_y             0.088433
# object_global_position_2d_z                  0.0
# Name: 11, dtype: object]
